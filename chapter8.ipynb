# %% [markdown]
# # chapter8. Data Wrangling:Join,Conbine

# %% [markdown]
# # 8.1 Hierachical indexing

# %% [markdown]
# 分层索引。在一个轴向上多重索引

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.Series(np.random.randn(9),index=[['a','a','a','b','b','c','c','d','d'],[1,2,3,1,3,1,2,2,3]])

# %%
data
# Out:
# a  1   -0.847017
#    2    0.611092
#    3    0.052586
# b  1    0.627202
#    3    0.122024
# c  1    1.362405
#    2   -0.327577
# d  2   -1.150721
#    3    0.544408
# dtype: float64

# %%
data.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %% [markdown]
# 部分索引

# %%
data['b']
# Out:
# 1    0.627202
# 3    0.122024
# dtype: float64

# %%
data['b':'c']
# Out:
# b  1    0.627202
#    3    0.122024
# c  1    1.362405
#    2   -0.327577
# dtype: float64

# %%
data.loc[['b','d']]
# Out:
# b  1    0.627202
#    3    0.122024
# d  2   -1.150721
#    3    0.544408
# dtype: float64

# %%
data.loc[:,2]
# Out:
# a    0.611092
# c   -0.327577
# d   -1.150721
# dtype: float64

# %% [markdown]
# unstack 堆叠对成二维

# %%
data.unstack()
# Out:
#           1         2         3
# a  2.239927  0.773124  0.831432
# b  1.201596       NaN  0.687725
# c -0.736098  0.028569       NaN
# d       NaN  0.203591 -0.679098

# %% [markdown]
# 可逆操作

# %%
data.unstack().stack()
# Out:
# a  1    2.239927
#    2    0.773124
#    3    0.831432
# b  1    1.201596
#    3    0.687725
# c  1   -0.736098
#    2    0.028569
# d  2    0.203591
#    3   -0.679098
# dtype: float64

# %% [markdown]
# DataFrame的操作

# %%
frame = pd.DataFrame(np.arange(12).reshape((4,3)),index=[['a','a','b','b'],[1,2,1,2]],columns=[['Ohio','Ohio','Colorado'],['Green','Red','Green']])

# %%
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names=['key1','key2']

# %%
frame.columns.names=['state','color']

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame['Ohio']
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
from pandas import MultiIndex

# %%
MultiIndex.from_arrays([['Ohio','Ohio','Colorado'],['Green','Red','Green']],names=['state','color'])
# Out:
# MultiIndex([(    'Ohio', 'Green'),
#             (    'Ohio',   'Red'),
#             ('Colorado', 'Green')],
#            names=['state', 'color'])

# %%
frame.columns
# Out:
# MultiIndex([(    'Ohio', 'Green'),
#             (    'Ohio',   'Red'),
#             ('Colorado', 'Green')],
#            names=['state', 'color'])

# %%
frame.columns=MultiIndex.from_arrays([['Ohio','Ohio','Colorado'],['Green','Red','Green']],names=['state','color'])

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %% [markdown]
# # 8.1.1 Recordering and sorting levels

# %% [markdown]
# 交换层级，数据不变

# %%
frame.swaplevel('key1','key2')
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %% [markdown]
# 只能在单一层级进行排序

# %%
frame.sort_index(level=1)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
# b    1        6   7        8
# a    2        3   4        5
# b    2        9  10       11

# %%
frame.swaplevel(0,1).sort_index(level=0)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %% [markdown]
# # 8.1.2 Summany Statisticas by Level

# %% [markdown]
# 指定的行列进行聚合

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.sum(level='key2')
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.sum(level='color',axis=1)
# Out:
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
frame.sum(level='state',axis=1)
# Out:
# state      Ohio  Colorado
# key1 key2
# a    1        1         2
#      2        7         5
# b    1       13         8
#      2       19        11

# %% [markdown]
# # 8.1.3 Indexing with a DataFrame's columns

# %% [markdown]
# 将索引移动到列中

# %%
frame=pd.DataFrame({'a':range(7),'b':range(7,0,-1),'c':['one','one','one','two','two','twp','two'],'d':[0,1,2,0,1,2,3]})

# %%
frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  twp  2
# 6  6  1  two  3

# %%
frame1=frame.stack()

# %%
frame1
# Out:
# 0  a      0
#    b      7
#    c    one
#    d      0
# 1  a      1
#    b      6
#    c    one
#    d      1
# 2  a      2
#    b      5
#    c    one
#    d      2
# 3  a      3
#    b      4
#    c    two
#    d      0
# 4  a      4
#    b      3
#    c    two
#    d      1
# 5  a      5
#    b      2
#    c    twp
#    d      2
# 6  a      6
#    b      1
#    c    two
#    d      3
# dtype: object

# %%
frame1.index.names=['level_0','lavel_1']

# %%
frame1
# Out:
# level_0  lavel_1
# 0        a            0
#          b            7
#          c          one
#          d            0
# 1        a            1
#          b            6
#          c          one
#          d            1
# 2        a            2
#          b            5
#          c          one
#          d            2
# 3        a            3
#          b            4
#          c          two
#          d            0
# 4        a            4
#          b            3
#          c          two
#          d            1
# 5        a            5
#          b            2
#          c          twp
#          d            2
# 6        a            6
#          b            1
#          c          two
#          d            3
# dtype: object

# %%
frame.stack().reset_index().set_index(['level_0','level_1'])
# Out:
#                    0
# level_0 level_1
# 0       a          0
#         b          7
#         c        one
#         d          0
# 1       a          1
#         b          6
#         c        one
#         d          1
# 2       a          2
#         b          5
#         c        one
#         d          2
# 3       a          3
#         b          4
#         c        two
#         d          0
# 4       a          4
#         b          3
#         c        two
#         d          1
# 5       a          5
#         b          2
#         c        twp
#         d          2
# 6       a          6
#         b          1
#         c        two
#         d          3

# %% [raw]
# set-index会生成新的dataframe

# %%
frame2 = frame.set_index(['c','d'])

# %%
frame2
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
# twp 2  5  2
# two 3  6  1

# %%
frame.set_index(['c','d'],drop=False)
# Out:
#        a  b    c  d
# c   d
# one 0  0  7  one  0
#     1  1  6  one  1
#     2  2  5  one  2
# two 0  3  4  two  0
#     1  4  3  two  1
# twp 2  5  2  twp  2
# two 3  6  1  two  3

# %%
frame2.reset_index()
# Out:
#      c  d  a  b
# 0  one  0  0  7
# 1  one  1  1  6
# 2  one  2  2  5
# 3  two  0  3  4
# 4  two  1  4  3
# 5  twp  2  5  2
# 6  two  3  6  1

# %%
df1 = pd.DataFrame({'key':['b','b','a','c','a','a','b'],"data1":range(7)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f144505e9826> in <module>
# ----> 1 df1 = pd.DataFrame({'key':['b','b','a','c','a','a','b'],"data1":range(7)})
#
# NameError: name 'pd' is not defined

# %%
df2 = pd.DataFrame({'key':['a','b','d'],'data2':range(3)})

# %%
pd.merge(df1,df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
pd.merge(df1,df2,on='key')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
df1 = pd.DataFrame({'key1':['b','b','a','c','a','a','b'],'data1':range(7)})
df2 = pd.DataFrame({'key2':['a','b','d'],'data2':range(3)})

# %%
pd.merge(df1,df2,left_on='key1',right_on='key2')
# Out:
#   key1  data1 key2  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
pd.merge(df1,df2,left_on='key1',right_on='key2',how="outer")
# Out:
#   key1  data1 key2  data2
# 0    b    0.0    b    1.0
# 1    b    1.0    b    1.0
# 2    b    6.0    b    1.0
# 3    a    2.0    a    0.0
# 4    a    4.0    a    0.0
# 5    a    5.0    a    0.0
# 6    c    3.0  NaN    NaN
# 7  NaN    NaN    d    2.0

# %%
df1 = pd.DataFrame({'key':['b','b','a','c','a','a','b'],'data1':range(7)})
df2 = pd.DataFrame({'key':['a','b','a','b','d'],'data2':range(5)})

# %%
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   a      2
# 3   b      3
# 4   d      4

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#    key  data1  data2
# 0    b      0    1.0
# 1    b      0    3.0
# 2    b      1    1.0
# 3    b      1    3.0
# 4    a      2    0.0
# 5    a      2    2.0
# 6    c      3    NaN
# 7    a      4    0.0
# 8    a      4    2.0
# 9    a      5    0.0
# 10   a      5    2.0
# 11   b      6    1.0
# 12   b      6    3.0

# %%
pd.merge(df1,df2,how = 'inner')
# Out:
#    key  data1  data2
# 0    b      0      1
# 1    b      0      3
# 2    b      1      1
# 3    b      1      3
# 4    b      6      1
# 5    b      6      3
# 6    a      2      0
# 7    a      2      2
# 8    a      4      0
# 9    a      4      2
# 10   a      5      0
# 11   a      5      2

# %%
left=pd.DataFrame({'key1':['foo','foo','bar'],'key2':['one','two','one'],'lval':[1,2,3]})
right=pd.DataFrame({'key1':['foo','foo','bar',"bar"],'key2':['one','one','one','two'],'lval':[4,5,6,7]})

# %%
pd.merge(left,right,on=['key1','key2'], how='outer')
# Out:
#   key1 key2  lval_x  lval_y
# 0  foo  one     1.0     4.0
# 1  foo  one     1.0     5.0
# 2  foo  two     2.0     NaN
# 3  bar  one     3.0     6.0
# 4  bar  two     NaN     7.0

# %%
pd.merge(left,right,on="key1")
# Out:
#   key1 key2_x  lval_x key2_y  lval_y
# 0  foo    one       1    one       4
# 1  foo    one       1    one       5
# 2  foo    two       2    one       4
# 3  foo    two       2    one       5
# 4  bar    one       3    one       6
# 5  bar    one       3    two       7

# %%
pd.merge(left,right,on="key1",suffixes=('_left','_right'))
# Out:
#   key1 key2_left  lval_left key2_right  lval_right
# 0  foo       one          1        one           4
# 1  foo       one          1        one           5
# 2  foo       two          2        one           4
# 3  foo       two          2        one           5
# 4  bar       one          3        one           6
# 5  bar       one          3        two           7

# %%
left1=pd.DataFrame({'key':['a','b','a','a','b','c'],'value':range(6)})
right1=pd.DataFrame({'group_val':['3.5','6']},index=['a','b'])

# %%
left1
# Out:
#   key  value
# 0   a      0
# 1   b      1
# 2   a      2
# 3   a      3
# 4   b      4
# 5   c      5

# %%
right1
# Out:
#   group_val
# a       3.5
# b         6

# %%
pd.merge(left1,right1,left_on="key",right_index=True)
# Out:
#   key  value group_val
# 0   a      0       3.5
# 2   a      2       3.5
# 3   a      3       3.5
# 1   b      1         6
# 4   b      4         6

# %%
pd.merge(left1,right1,left_on="key",right_index=True, how='outer')
# Out:
#   key  value group_val
# 0   a      0       3.5
# 2   a      2       3.5
# 3   a      3       3.5
# 1   b      1         6
# 4   b      4         6
# 5   c      5       NaN

# %%
lefth = pd.DataFrame({'key1':['Ohio','Ohio','Ohio','Nevada','Nevada'],'key2':[2000,2001,2002,2001,2002],'data':np.arange(5.)})
righth = pd.DataFrame(np.arange(12).reshape((6,2)),index=[['Nevada','Nevada',"Ohio","Ohio","Ohio","Ohio"],[2001,2000,2000,2000,2001,2002]],columns=['event1','event2'])

# %%
lefth
# Out:
#      key1  key2  data
# 0    Ohio  2000   0.0
# 1    Ohio  2001   1.0
# 2    Ohio  2002   2.0
# 3  Nevada  2001   3.0
# 4  Nevada  2002   4.0

# %%
righth
# Out:
#              event1  event2
# Nevada 2001       0       1
#        2000       2       3
# Ohio   2000       4       5
#        2000       6       7
#        2001       8       9
#        2002      10      11

# %%
pd.merge(lefth,righth, left_on=['key1','key2'],right_index=True)
# Out:
#      key1  key2  data  event1  event2
# 0    Ohio  2000   0.0       4       5
# 0    Ohio  2000   0.0       6       7
# 1    Ohio  2001   1.0       8       9
# 2    Ohio  2002   2.0      10      11
# 3  Nevada  2001   3.0       0       1

# %%
pd.merge(lefth,righth, left_on=['key1','key2'],right_index=True,how="outer")
# Out:
#      key1  key2  data  event1  event2
# 0    Ohio  2000   0.0     4.0     5.0
# 0    Ohio  2000   0.0     6.0     7.0
# 1    Ohio  2001   1.0     8.0     9.0
# 2    Ohio  2002   2.0    10.0    11.0
# 3  Nevada  2001   3.0     0.0     1.0
# 4  Nevada  2002   4.0     NaN     NaN
# 4  Nevada  2000   NaN     2.0     3.0

# %%
left2 = pd.DataFrame([[1.,2.],[3.,4.],[5.,6.]],index=['a','c','e'],columns=['Ohio','Navada'])
right2 = pd.DataFrame([[7.,8.],[9.,10.],[11.,12.],[13,14]],index=['b','c','d','e'],columns=['Missouri','Albama'])

# %%
left2
# Out:
#    Ohio  Navada
# a   1.0     2.0
# c   3.0     4.0
# e   5.0     6.0

# %%
right2
# Out:
#    Missouri  Albama
# b       7.0     8.0
# c       9.0    10.0
# d      11.0    12.0
# e      13.0    14.0

# %%
pd.merge(left2,right2,how='outer',left_index=True,right_index=True)
# Out:
#    Ohio  Navada  Missouri  Albama
# a   1.0     2.0       NaN     NaN
# b   NaN     NaN       7.0     8.0
# c   3.0     4.0       9.0    10.0
# d   NaN     NaN      11.0    12.0
# e   5.0     6.0      13.0    14.0

# %%
left2.join(right2,how='outer')
# Out:
#    Ohio  Navada  Missouri  Albama
# a   1.0     2.0       NaN     NaN
# b   NaN     NaN       7.0     8.0
# c   3.0     4.0       9.0    10.0
# d   NaN     NaN      11.0    12.0
# e   5.0     6.0      13.0    14.0

# %%
left1.join(right2,on='key')
# Out:
#   key  value  Missouri  Albama
# 0   a      0       NaN     NaN
# 1   b      1       7.0     8.0
# 2   a      2       NaN     NaN
# 3   a      3       NaN     NaN
# 4   b      4       7.0     8.0
# 5   c      5       9.0    10.0
